# %%
import keras
import densenet

keras.backend.set_image_data_format('channels_first')

# %%
image_dim = (2, 100, 100)
model = densenet.DenseNet(classes=1, input_shape=image_dim, depth=64, growth_rate=12, bottleneck=True, reduction=0.5)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_10 (InputLayer)           (None, 2, 100, 100)  0
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, 24, 100, 100) 432         input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_386 (BatchN (None, 24, 100, 100) 96          conv2d_386[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, 24, 100, 100) 0           batch_normalization_386[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, 48, 100, 100) 1152        activation_384[0][0]
# ...

# %%
from densenetlst import DenseNet

image_dim = (2, 100, 100)
model = DenseNet(classes=1, input_shape=image_dim, depth=64, growth_rate=12, bottleneck=True, reduction=0, activation='sigmoid')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_12 (InputLayer)           (None, 2, 100, 100)  0
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 24, 100, 100) 432         input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_512 (BatchN (None, 24, 100, 100) 96          conv2d_512[0][0]
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 24, 100, 100) 0           batch_normalization_512[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, 48, 100, 100) 1152        activation_510[0][0]
# ...

# %%
from densenetlst import DenseNet

image_dim = (2, 100, 100)
model = DenseNet(classes=1, input_shape=image_dim, nb_dense_block=3, growth_rate=24, nb_layers_per_block=[5,5,5,5], bottleneck=True, reduction=0, activation='sigmoid')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-f5f50013e924> in <module>
#       2
#       3 image_dim = (2, 100, 100)
# ----> 4 model = DenseNet(classes=1, input_shape=image_dim, nb_dense_block=3, growth_rate=24, nb_layers_per_block=[5,5,5,5], bottleneck=True, reduction=0, activation='sigmoid')
#       5 model.summary()
#
# ~/ctasoft/cta-lstchain/cnn/densenetlst.py in DenseNet(input_shape, depth, nb_dense_block, growth_rate, nb_filter, nb_layers_per_block, bottleneck, reduction, dropout_rate, weight_decay, subsample_initial_block, include_top, classes, activation)
#     262     x = __create_dense_net(classes, img_input, include_top, depth, nb_dense_block,
#     263                            growth_rate, nb_filter, nb_layers_per_block, bottleneck, reduction,
# ...

# %%
from regressors import DenseNet

channels = 2
img_rows = 100
img_cols = 100
depth = 121
outcomes = 1
nb_dense_block = 4
growth_rate = 32
nb_filter = 64
nb_layers_per_block = [6, 12, 24, 16]
bottleneck = True
subsample_initial_block = False
reduction = 0.5
densenet = DenseNet(channels, img_rows, img_cols, outcomes, depth=depth, nb_dense_block=nb_dense_block,
                    growth_rate=growth_rate, nb_filter=nb_filter, nb_layers_per_block=nb_layers_per_block,
                    bottleneck=bottleneck, subsample_initial_block=subsample_initial_block, reduction=reduction)
model = densenet.get_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 100, 100, 2)  0
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 100, 100, 64) 1152        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 100, 100, 64) 256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 100, 100, 64) 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 100, 100, 128 8192        activation_122[0][0]
# ...
