# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
from ctapipe.instrument import CameraGeometry
from ctapipe.visualization import CameraDisplay

# %%
#path='/mnt/Dati/CTA_DATA_EXT/interp/gamma_diff/gamma-diffuse_20deg_180deg_runs131-140___cta-prod3-demo-2147m-LaPalma-baseline-mono_interp.h5'
path = '/mnt/Dati/CTA_DATA_EXT/data/interp/proton_20deg_180deg_runs101-110___cta-prod3-demo-2147m-LaPalma-baseline-mono_interp.h5'

# %%
file = h5py.File(path, 'r')

# %%
list(file.keys())
# Out:
# ['Event_Info', 'LST']

# %%
LST = file['LST']
list(LST.keys())
# Out:
# ['LST_event_index',
#  'LST_image_charge',
#  'LST_image_charge_interp',
#  'LST_image_peak_times',
#  'LST_image_peak_times_interp',
#  'delta_alt',
#  'delta_az',
#  'intensities',
#  'intensities_width_2']

# %%
orig_crg = LST['LST_image_charge'][:]
intensities = LST['intensities'][:]
leakage2 = LST['intensities_width_2'][:]
interp_crg = LST['LST_image_charge_interp'][:][(intensities>50)&(leakage2<0.2)]
interp_time = LST['LST_image_peak_times_interp'][:][(intensities>50)&(leakage2<0.2)]
lbl = [0]*len(interp_crg)

# %%
interp

# %%
drago = []
for i in range(10):
    prova = LST['LST_image_charge_interp'][i]
    drago.append(prova)
drago = np.array(drago).reshape(-1,100,100,1)
print(drago.shape)
drago = drago.reshape(-1,100,100)
print(drago.shape)#print(drago.shape, drago.shape[1], drago.shape[2])
#for d in drago:
#    print(d.shape)
# Out:
# (10, 100, 100, 1)
# (10, 100, 100)

# %%
cam = CameraGeometry.from_name('LSTCam')
x = cam.pix_x
y = cam.pix_y
points = np.array([np.array(x),
                   np.array(y)]).T


fig_org = plt.figure(figsize=(15, 12))
fig_interp = plt.figure(figsize=(12, 12))
fig_org.tight_layout()

# %%
print(x.max(), x.min())
# Out:
# 1.171686293234585 m -1.171686293234585 m

# %%
fig_interp = plt.figure(figsize=(12, 12))
plt.imshow(interp_crg[10].T, extent=(points.min(), points.max(), points.min(), points.max()), origin='lower')
plt.savefig("provaint.png")

# %%
fig_interp = plt.figure(figsize=(12, 12))
plt.imshow(interp_time[10].T, extent=(points.min(), points.max(), points.min(), points.max()), origin='lower')
plt.savefig("provaint.png")

# %%
plt.figure(figsize=(20, 16))
display = CameraDisplay(cam)
display.add_colorbar()
#display.autoscale
#fig.tight_layout()
i=10
#for i in range(100):
display.image = orig_crg[i]
plt.show()
#lt.savefig("./images/{}.svg".format(i))

# %%
interp_crg.shape
# Out:
# (1420, 100, 100)

# %%
cam = CameraGeometry.from_name('LSTCam')
x = cam.pix_x
y = cam.pix_y
points = np.array([np.array(x),
                   np.array(y)]).T
fig_interp = plt.figure(figsize=(8, 8))
plt.title('Gamma')
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.imshow(interp_crg[10].T, extent=(points.min(), points.max(), points.min(), points.max()), origin='lower')

# %%
len(list(enumerate(interp_crg)))
# Out:
# 1420

# %%
for i, ele in enumerate(interp_crg):
    print(i, ele.shape)
    break
# Out:
# 0 (100, 100)

# %% [raw]
# zd = LST['delta_alt'][:]

# %%
zd = LST['delta_alt'][:]

# %%
zd
# Out:
# array([38.47128084, 36.96659118, 42.61239297, ..., 40.09311819,
#        36.20674062, 36.20674062])

# %%
az = LST['delta_az'][:]

# %%
fig = plt.figure(figsize=(10,10))
dir = plt.hist2d(zd,az, bins=200)

# %%
d_squared = np.power(az,2) + np.power(zd,2)

# %%
fig, ax = plt.subplots()
ax.hist(d_squared, bins=50)
# Out:
# (array([  2.,   2.,   1.,   4.,   2.,   7.,   5.,  11.,  18.,  11.,  21.,
#          41.,  51.,  94.,  99., 135., 167., 209., 253., 201., 182., 217.,
#         118., 123.,  86.,  69.,  39.,  29.,  16.,  22.,  14.,   8.,   9.,
#          16.,   8.,   5.,   1.,   0.,  11.,   2.,   2.,   2.,   0.,   0.,
#           0.,   0.,   0.,   1.,   0.,   1.]),
#  array([ 770.30611057,  813.16895708,  856.03180359,  898.8946501 ,
#          941.75749661,  984.62034312, 1027.48318963, 1070.34603614,
#         1113.20888265, 1156.07172916, 1198.93457567, 1241.79742218,
#         1284.66026869, 1327.5231152 , 1370.38596171, 1413.24880822,
#         1456.11165473, 1498.97450124, 1541.83734775, 1584.70019426,
#         1627.56304077, 1670.42588728, 1713.28873379, 1756.1515803 ,
#         1799.01442681, 1841.87727332, 1884.74011983, 1927.60296634,
#         1970.46581285, 2013.32865936, 2056.19150587, 2099.05435238,
#         2141.91719889, 2184.7800454 , 2227.64289191, 2270.50573842,
# ...

# %%
fig = plt.figure(figsize=(10,10))
dir = plt.hist2d(xc,yc, bins=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-241c7b1a08bb> in <module>
#       1 fig = plt.figure(figsize=(10,10))
# ----> 2 dir = plt.hist2d(xc,yc, bins=200)
#
# NameError: name 'xc' is not defined

# %%
n = 10000
xp = np.random.random_sample(n)
yp = np.random.random_sample(n)
zp = np.random.random_sample(n)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(projection='3d')
ax.scatter(np.arccos(xp),np.arcsin(yp), np. marker='o')

plt.show()
