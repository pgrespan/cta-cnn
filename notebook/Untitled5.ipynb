# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = pd.read_pickle("/mnt/Dati/CTA/results/plike_gamma.pkl")

# %%
file
# Out:
#          file_idx  img_idx  event_idx    intensity  leakage2  class  \
# 0            10.0      0.0        0.0   172.082581  0.000000    1.0
# 1            10.0      1.0        1.0   567.250549  0.165889    1.0
# 2            10.0      2.0        1.0  2354.177246  0.000000    1.0
# 3            10.0      3.0        1.0  1413.055054  0.000000    1.0
# 4            10.0      4.0        1.0   496.169800  0.000000    1.0
# ...           ...      ...        ...          ...       ...    ...
# 1931099       4.0  97034.0    54398.0   204.897461  0.000000    1.0
# 1931100       4.0  97035.0    54400.0    40.722317  0.000000    1.0
# 1931101       4.0  97036.0    54401.0   171.398178  0.000000    1.0
# 1931102       4.0  97037.0    54402.0   201.304153  0.000000    1.0
# 1931103       4.0  97038.0    54403.0   160.044495  0.000000    1.0
#
#          energy_true    az         alt         d_alt      d_az
# 0          -1.642310  70.0  180.000005 -3.288022e-07  0.000002
# ...
